# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt

import scienceplots

# %%
deepconv = [199.8, 0.79]
unet = [14.1, 0.74]
att_unet = [225.8, 0.85]
segcaps = [33.9, 0.71]
u2net = [11.6, 0.91]

# %%
plt.style.use(['science','ieee','grid','no-latex'])
plt.scatter(deepconv[0], deepconv[1], marker='v', color='black',  facecolors='none', edgecolors='gray', s=80)
plt.scatter(unet[0], unet[1], marker='v', color='black', s=80)
plt.scatter(att_unet[0], att_unet[1], marker='v', color='green', s=80)
plt.scatter(segcaps[0], segcaps[1], marker='v', color='blue', s=80)
plt.scatter(u2net[0], u2net[1], marker='v', color='red', s=80)

plt.legend(['Deep Conv', 'U-Net', 'Attn U-Net', 'Capsule Net', 'U2-Net'], fontsize=7)
    
plt.xlabel("Model Size (MBs)", fontsize=14)
plt.ylabel("SSIM", fontsize=14)
# Out:
# Text(0, 0.5, 'SSIM')
